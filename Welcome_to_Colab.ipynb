# %% [markdown]
# <a href="https://colab.research.google.com/github/Akhileshchannappgol/ConfigServerReposiotry/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
people={'Arvind':{'age':30,"height":175},
        'bob':{'age':25,'height':150},
        'Charu':{'age':27,'height':165}
        }

# def get_age(name):
#     return people[name]['age']

# max_person = max(people, key=get_age)
# print(people[max_person])



max(people,key=lambda person:people[person]['age'])
# Out:
# 'Arvind'
