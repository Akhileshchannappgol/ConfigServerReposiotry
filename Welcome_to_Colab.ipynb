# %% [markdown]
# <a href="https://colab.research.google.com/github/Akhileshchannappgol/ConfigServerReposiotry/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1=[1,2,3,45,3]
list2=['a','b','c','d','e']

ziplist=zip(list1,list2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3657078125.py in <cell line: 0>()
#       2 list2=['a','b','c','d','e']
#       3
# ----> 4 ziplist=zip(list1,list2)
#
# TypeError: 'zip' object is not callable
